# %% [markdown]
# # Level 2
# This notebooks explains the process of obtaining the prior mean and variance estimates for Level 2.
#
# ## Context
# The agent measures the same stimulus through two cues (A,B) of different reliabilities. Cue B has a fixed, hidden standard deviation; cue A’s reliability can vary from trial to trial.
#
# What the agent does. It performs a Bayesian combination of both cues to form posterior estimates then compares these two estimates (S₁,S₂) and chooses 1 if S₁ > S₂, else 0.
#
# Your mission. By generating conflicts between A and B, determine the relative reliability of cue B compared to A.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import norm
import os

import bmpe as bmpe

from bmpe.utils import (
    binomial_loglik,
    fit_model, 
    cum_gauss,
    logistic
)
